# %% [markdown]
# <a href="https://colab.research.google.com/github/konchadahemasai/BASICML/blob/main/FINAL_PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# IMPORT LIBRARIES

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# DATA ACCESSING

# %%
data=pd.read_csv('heart.csv')
data.head(10)
# Out:
#    age  sex  cp  trtbps  chol  fbs  ...  exng  oldpeak  slp  caa  thall  output
# 0   63    1   3     145   233    1  ...     0      2.3    0    0      1       1
# 1   37    1   2     130   250    0  ...     0      3.5    0    0      2       1
# 2   41    0   1     130   204    0  ...     0      1.4    2    0      2       1
# 3   56    1   1     120   236    0  ...     0      0.8    2    0      2       1
# 4   57    0   0     120   354    0  ...     1      0.6    2    0      2       1
# 5   57    1   0     140   192    0  ...     0      0.4    1    0      1       1
# 6   56    0   1     140   294    0  ...     0      1.3    1    0      2       1
# 7   44    1   1     120   263    0  ...     0      0.0    2    0      3       1
# 8   52    1   2     172   199    1  ...     0      0.5    2    0      3       1
# 9   57    1   2     150   168    0  ...     0      1.6    2    0      2       1
#
# [10 rows x 14 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trtbps    303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slp       303 non-null    int64
#  11  caa       303 non-null    int64
#  12  thall     303 non-null    int64
#  13  output    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
data.describe()
# Out:
#               age         sex          cp  ...         caa       thall      output
# count  303.000000  303.000000  303.000000  ...  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  ...    0.729373    2.313531    0.544554
# std      9.082101    0.466011    1.032052  ...    1.022606    0.612277    0.498835
# min     29.000000    0.000000    0.000000  ...    0.000000    0.000000    0.000000
# 25%     47.500000    0.000000    0.000000  ...    0.000000    2.000000    0.000000
# 50%     55.000000    1.000000    1.000000  ...    0.000000    2.000000    1.000000
# 75%     61.000000    1.000000    2.000000  ...    1.000000    3.000000    1.000000
# max     77.000000    1.000000    3.000000  ...    4.000000    3.000000    1.000000
#
# [8 rows x 14 columns]

# %%
total=data.isnull().sum()

# %%
data.columns.values
# Out:
# array(['age', 'sex', 'cp', 'trtbps', 'chol', 'fbs', 'restecg', 'thalachh',
#        'exng', 'oldpeak', 'slp', 'caa', 'thall', 'output'], dtype=object)

# %%
data.duplicated().sum()
# Out:
# 1

# %% [markdown]
# DATA CLEANING

# %%
data.drop_duplicates(inplace=True)

# %%
data.drop("cp",axis=1,inplace=True)
data.head(10)
# Out:
#    age  sex  trtbps  chol  fbs  restecg  ...  exng  oldpeak  slp  caa  thall  output
# 0   63    1     145   233    1        0  ...     0      2.3    0    0      1       1
# 1   37    1     130   250    0        1  ...     0      3.5    0    0      2       1
# 2   41    0     130   204    0        0  ...     0      1.4    2    0      2       1
# 3   56    1     120   236    0        1  ...     0      0.8    2    0      2       1
# 4   57    0     120   354    0        1  ...     1      0.6    2    0      2       1
# 5   57    1     140   192    0        1  ...     0      0.4    1    0      1       1
# 6   56    0     140   294    0        0  ...     0      1.3    1    0      2       1
# 7   44    1     120   263    0        1  ...     0      0.0    2    0      3       1
# 8   52    1     172   199    1        1  ...     0      0.5    2    0      3       1
# 9   57    1     150   168    0        1  ...     0      1.6    2    0      2       1
#
# [10 rows x 13 columns]

# %%
data.shape
# Out:
# (302, 14)

# %%
from statistics import mode
mode=mode(data.caa)
data.loc[data.caa == 4, 'caa'] = mode
data.caa.value_counts()
# Out:
# 0    179
# 1     65
# 2     38
# 3     20
# Name: caa, dtype: int64

# %% [markdown]
# **DATA VISUALIZATION**

# %%
from matplotlib import pyplot as plt
from matplotlib import style
import seaborn as sns

# %% [markdown]
# AGE DISTRIBUTION
#
# ---

# %%
X=data["age"]
plt.hist(X,color="violet")
plt.title("Age distribution",fontsize=25)
plt.xlabel("Age",fontsize=10)
plt.ylabel("Frequancy",fontsize=10)
plt.grid(False)
plt.gcf().set_size_inches(6,6)
plt.show()

# %% [markdown]
# SEX DISTRIBUTION
#
# ---

# %%
X=data["sex"].value_counts().index
print(X)
Y=data["sex"].value_counts()
print(Y)
sns.countplot(data=data,x="sex")
plt.bar(X,Y,color=["blue","black"])
plt.tight_layout()
plt.xlabel("Sex_Category",color="black",fontsize=20)
plt.ylabel("Count",color="black",fontsize=20)
plt.title("Sex-distribution",color="black",fontsize=25)
plt.gcf().set_size_inches(6,6)
plt.show()
# Out:
# Int64Index([1, 0], dtype='int64')
# 1    206
# 0     96
# Name: sex, dtype: int64

# %% [markdown]
# CATEGORIES OF CHEST PAIN(cp)
#
# ---

# %%
X=data["cp"].value_counts().index
X
Y=data["cp"].value_counts()
print(Y)
myexplode=(0,0.1,0,0.1)
mylabel=["Typical angina(0)","Atypical(1)","Non_aniginal pain(2)","Asymptomatic pain(3)"]

plt.pie(Y,labels=mylabel,autopct="%1.1f%%",startangle=15,shadow=True,explode=myexplode)
plt.axis("equal")
plt.gcf().set_size_inches(6,6)
plt.show()
# Out:
# 0    143
# 2     86
# 1     50
# 3     23
# Name: cp, dtype: int64

# %%
sns.countplot(data=data,x="chol")
#plt.bar(X,Y,color=["orange","black","pink","blue"])
plt.xlabel("cp(chest pain)",fontsize=20)
plt.ylabel("count",fontsize=20)
plt.tight_layout()
plt.grid(True)
plt.gcf().set_size_inches(6,6)
plt.show()

# %% [markdown]
# LINEPLOT(AGE) WITH VARIOUS VARIABLES
#
# ---

# %% [markdown]
# with blood pressure
#
# ---

# %%
plt.style.use("fivethirtyeight")
plt.title("Effect of age on blood pressure",fontsize=20)
sns.lineplot(data['age'],data['trtbps'])
plt.gcf().set_size_inches(6,6)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# with cholestor level
#
# ---

# %%
plt.style.use("fivethirtyeight")
plt.title("Effect of age on cholestor level",fontsize=20)
sns.lineplot(x=data["age"],y=data["chol"])
plt.gcf().set_size_inches(6,6)

# %% [markdown]
# with heart rate
#
# ---

# %%
plt.style.use("fivethirtyeight")
plt.title("Effect of age on heart rate",fontsize=20)
sns.lineplot(x=data["age"],y=data["thalachh"])
plt.gcf().set_size_inches(6,6)

# %% [markdown]
# with rate of heart attack
#
# ---

# %%
plt.style.use("fivethirtyeight")
plt.title("Effect of age on rate of heart attack",fontsize=20)
sns.lineplot(x=data["age"],y=data["output"])
plt.gcf().set_size_inches(6,6)

# %% [markdown]
# BAR PLOT(SEX)
#
# ---

# %%
hue_color={0:'red',1:'black'}
sex=['female','male']
ax=sns.countplot(data=data,x='sex',hue='output',palette=hue_color)
plt.xticks(ticks = [0,1], labels = sex)
plt.legend(['less chance', 'high chance'])
plt.gcf().set_size_inches(6,6)
plt.show()

# %% [markdown]
# COUNT PLOT
#
# ---

# %%
hue_color={0:'green',1:'black'}
ax=sns.countplot(data=data,x='cp',hue='output',palette=hue_color)
plt.legend(['less chance', 'high chance'])
plt.gcf().set_size_inches(6,6)
plt.show()

# %% [markdown]
# KDEPLOT(RESTING BP)
#
# ---

# %%
ax = sns.kdeplot(data = data, x = 'trtbps', bw_adjust = 0.9, hue = 'output', palette = ['blue', 'black'])
ax.set(xlabel = 'resting blood pressure')
plt.legend(['high chance', 'low chance'])
plt.gcf().set_size_inches(6,6)
plt.show()

# %% [markdown]
# KDEPLOT(CHOLESTROL)
#
# ---

# %%
ax = sns.kdeplot(data = data, x = 'chol', bw_adjust = 0.9, hue = 'output', palette = ['yellow', 'black'])
ax.set(xlabel = 'cholestrol')
plt.legend(['high chance', 'low chance'])
plt.gcf().set_size_inches(6,6)
plt.show()

# %% [markdown]
# COUNT PLOT(FBS)
#
# ---

# %%
hue_color={0:'white',1:'black'}
# fbs=['true','false']
ax=sns.countplot(data=data,x='fbs',hue='output',palette=hue_color)
# plt.xticks(ticks = [0,1], labels = fbs)
plt.legend(['less chance', 'high chance'])
plt.gcf().set_size_inches(6,6)
plt.show()

# %% [markdown]
# COUNT PLOT(RESTECG)
#
# ---

# %%
hue_color={0:'blue',1:'yellow'}
# fbs=['true','false']
ax=sns.countplot(data=data,x='restecg',hue='output',palette=hue_color)
# plt.xticks(ticks = [0,1], labels = fbs)
plt.legend(['less chance', 'high chance'])
plt.gcf().set_size_inches(6,6)
plt.show()

# %% [markdown]
# KDEPLOT(HEART RATE)
#
# ---

# %%
ax = sns.kdeplot(data = data, x = 'thalachh', bw_adjust = 0.9, hue = 'output', palette = ['blue', 'black'])
ax.set(xlabel = 'Heart rate')
plt.legend(['high chance', 'low chance'])
plt.gcf().set_size_inches(6,6)
plt.show()

# %% [markdown]
# COUNT PLOT(EXNG)

# %%
hue_color={0:'green',1:'black'}
ax=sns.countplot(data=data,x='exng',hue='output',palette=hue_color)
plt.legend(['less chance', 'high chance'])
plt.gcf().set_size_inches(6,6)
plt.show()

# %% [markdown]
# KDEPLOT(OLD PEAK)
#
# ---

# %%
ax = sns.kdeplot(data = data, x = 'oldpeak', bw_adjust = 0.9, hue = 'output', palette = ['blue', 'yellow'])
ax.set(xlabel = 'oldpeak')
plt.legend(['high chance', 'low chance'])
plt.gcf().set_size_inches(6,6)
plt.show()

# %% [markdown]
# COUNTPLOT(SLP)
#
# ---

# %%
hue_color={0:'red',1:'black'}
ax=sns.countplot(data=data,x='slp',hue='output',palette=hue_color)
plt.legend(['less chance', 'high chance'])
plt.gcf().set_size_inches(6,6)
plt.show()

# %% [markdown]
# COUNT PLOT(SPA)
#
# ---

# %%
hue_color={0:'green',1:'black'}
ax=sns.countplot(data=data,x='caa',hue='output',palette=hue_color)
plt.legend(['less chance', 'high chance'])
plt.gcf().set_size_inches(6,6)
plt.show()

# %% [markdown]
# COUNT PLOT(THALL)
#
# ---

# %%
hue_color={0:'green',1:'black'}
ax=sns.countplot(data=data,x='thall',hue='output',palette=hue_color)
plt.legend(['less chance', 'high chance'])
plt.gcf().set_size_inches(6,6)
plt.show()

# %% [markdown]
# **MACHINE LEARNING MODELS**
#
# ---

# %% [markdown]
# LOGISTIC REGRESSION
#
# ---

# %%
data
# Out:
#      age  sex  cp  trtbps  chol  fbs  ...  exng  oldpeak  slp  caa  thall  output
# 0     63    1   3     145   233    1  ...     0      2.3    0    0      1       1
# 1     37    1   2     130   250    0  ...     0      3.5    0    0      2       1
# 2     41    0   1     130   204    0  ...     0      1.4    2    0      2       1
# 3     56    1   1     120   236    0  ...     0      0.8    2    0      2       1
# 4     57    0   0     120   354    0  ...     1      0.6    2    0      2       1
# ..   ...  ...  ..     ...   ...  ...  ...   ...      ...  ...  ...    ...     ...
# 298   57    0   0     140   241    0  ...     1      0.2    1    0      3       0
# 299   45    1   3     110   264    0  ...     0      1.2    1    0      3       0
# 300   68    1   0     144   193    1  ...     0      3.4    1    2      3       0
# 301   57    1   0     130   131    0  ...     1      1.2    1    1      3       0
# ...

# %%
X=data.iloc[:,:13]
X
# Out:
#      age  sex  cp  trtbps  chol  fbs  ...  thalachh  exng  oldpeak  slp  caa  thall
# 0     63    1   3     145   233    1  ...       150     0      2.3    0    0      1
# 1     37    1   2     130   250    0  ...       187     0      3.5    0    0      2
# 2     41    0   1     130   204    0  ...       172     0      1.4    2    0      2
# 3     56    1   1     120   236    0  ...       178     0      0.8    2    0      2
# 4     57    0   0     120   354    0  ...       163     1      0.6    2    0      2
# ..   ...  ...  ..     ...   ...  ...  ...       ...   ...      ...  ...  ...    ...
# 298   57    0   0     140   241    0  ...       123     1      0.2    1    0      3
# 299   45    1   3     110   264    0  ...       132     0      1.2    1    0      3
# 300   68    1   0     144   193    1  ...       141     0      3.4    1    2      3
# 301   57    1   0     130   131    0  ...       115     1      1.2    1    1      3
# ...

# %%
Y=data.iloc[:,13:]
Y
# Out:
#      output
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ..      ...
# 298       0
# 299       0
# 300       0
# 301       0
# 302       0
#
# [302 rows x 1 columns]

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,confusion_matrix,plot_confusion_matrix,accuracy_score
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.fit_transform(X_test)
Y_train=np.ravel(Y_train)
clf=LogisticRegression()
clf.fit(X_train,Y_train)
pred=clf.predict(X_test)
log_acc=accuracy_score(pred,Y_test);
print("REPORT: ")
print(confusion_matrix(Y_test,pred))
print(classification_report(Y_test,pred))
plot_confusion_matrix(clf,X_test,Y_test)
plt.grid(False)
plt.gcf().set_size_inches(6,6)
# Out:
# REPORT:
# [[20  5]
#  [ 3 33]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.80      0.83        25
#            1       0.87      0.92      0.89        36
#
#     accuracy                           0.87        61
#    macro avg       0.87      0.86      0.86        61
# weighted avg       0.87      0.87      0.87        61

# %% [markdown]
# KNEIGHBOURSCLASSIFIER
#
# ---

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
clf=KNeighborsClassifier(n_neighbors=9)
clf.fit(X_train,Y_train)
pred=clf.predict(X_test)
knn=accuracy_score(pred,Y_test);
print("REPORT: ")
print(confusion_matrix(Y_test,pred))
print(classification_report(Y_test,pred))
plot_confusion_matrix(clf,X_test,Y_test)
plt.grid(False)
plt.gcf().set_size_inches(6,6)
# Out:
# REPORT:
# [[19  6]
#  [ 4 32]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.76      0.79        25
#            1       0.84      0.89      0.86        36
#
#     accuracy                           0.84        61
#    macro avg       0.83      0.82      0.83        61
# weighted avg       0.84      0.84      0.83        61

# %% [markdown]
# DECISIONTREECLASSIFIER
#
# ---

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf=DecisionTreeClassifier(criterion="entropy", max_depth=3)
clf.fit(X_train,Y_train)
pred=clf.predict(X_test)
dtc=accuracy_score(pred,Y_test);
print("REPORT: ")
print(confusion_matrix(Y_test,pred))
print(classification_report(Y_test,pred))
plot_confusion_matrix(clf,X_test,Y_test)
plt.grid(False)
plt.gcf().set_size_inches(6,6)
# Out:
# REPORT:
# [[20  5]
#  [ 6 30]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.80      0.78        25
#            1       0.86      0.83      0.85        36
#
#     accuracy                           0.82        61
#    macro avg       0.81      0.82      0.81        61
# weighted avg       0.82      0.82      0.82        61

# %% [markdown]
# RANDOMFORESTCLASSIFIER
#
# ---

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf = RandomForestClassifier(n_estimators = 100)
clf.fit(X_train,Y_train)
pred=clf.predict(X_test)
rcf=accuracy_score(pred,Y_test);
print("REPORT: ")
print(confusion_matrix(Y_test,pred))
print(classification_report(Y_test,pred))
plot_confusion_matrix(clf,X_test,Y_test)
plt.grid(False)
plt.gcf().set_size_inches(6,6)
# Out:
# REPORT:
# [[19  6]
#  [ 5 31]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.76      0.78        25
#            1       0.84      0.86      0.85        36
#
#     accuracy                           0.82        61
#    macro avg       0.81      0.81      0.81        61
# weighted avg       0.82      0.82      0.82        61

# %% [markdown]
# **FINAL REPORT ON 4 MACHINE LEARNING MODELS**
#
# ---

# %%
print("Accuracy of Logistic Regression : ",log_acc)
print("Accuracy of Decision Tree Classifier : ",dtc)
print("Accuracy of KNN Classifier : ",knn)
print("Accuracy of Random Forest Classifier : ",rcf)
models_acc=[log_acc,dtc,knn,rcf]
names_of_models=['LogisticRegression','DecisionTreeClassifier','KNNClassifier','RandomForestClassifier'];
sns.barplot(y=names_of_models,x=models_acc)
plt.gcf().set_size_inches(6,6)
plt.xlim([0.6,1.0])
# Out:
# Accuracy of Logistic Regression :  0.8688524590163934
# Accuracy of Decision Tree Classifier :  0.819672131147541
# Accuracy of KNN Classifier :  0.8360655737704918
# Accuracy of Random Forest Classifier :  0.819672131147541
# (0.6, 1.0)

# %% [markdown]
# ***OBSERVATION***
#
# ---

# %% [markdown]
# Here we have considered a large dataset regarding to the problems of heart faced by the people.This dataset may explain more about these features.To explore this data and to gain required information from the dataset we must apply exploratory data analysis,splitting the data using sklearn and some of the machine learning  models for the accurate output.

# %% [markdown]
# 1.   EXPLORATORY DATA ANALYSIS:
# EDA in python uses data visualization to draw meaningful patterns and insights.It also involves the preparation of datasets for analysis by removing irregularities in the data.in this project we have represented the data with various types of graphs like lineplot,countplot,kdeplot,piechart,bargraph with various variables.from the sex barplot
# 1. Males have less chances of getting heart attack than females.
#
# 2.A signifciant number of males are at less risk compared to no of males with high risk.
#
# 3.A signifciant number of females are at high risk compared to number of females with less risk
# from chestpain barplot
# 1. Patients with chest pain 0 have less chances of heart attack as compared to others chest pains.
#
# 2.. Patients with chest pain 1,2 are at high risk.
# from kdeplot (bp)
# 1.Patients who have resting blood pressure with range between 80 and 150 have high chance of being at high risk
# from kdeplot (cholestrol)
# 1.Patients with cholestrol value between 100 to 300 have high chances of heart attack
# from countplot od fbs
# 1.There isn't much correlation between the target variable(output)
# from count plot of restecg
# 1. Patients with value 1 have high chances of heart attack risk.
#
# 2.Patients with value 0 are with less risk level.
# from kdeplot(thall)
# 1. Patients with heart rate greater than 100 have high chances of heart attack.
#
# Patients with heart rate less than 100 have less chances of heart attack
# from countplot (exng)
# 1. Patients with 0 value of exng have high chances of heart attack.
#
# Patients with 1 value of exng have less chances of heart attack compared to high chances of heart attcak.
# from kdeplot(oldpeak)
#  1. Patients with lower values are at high risk.
#
# 2.Patients with high values are at low risk.
# from countplot(slp)
# 1.Patients with 0 value of slp have bad correlation with output variable.
#
# 2.Patients with 2 value of slp have high risk of getting heart attack.
#
# 3.Patients with value 1 of slp having less risk of getting heart attack.
# from countplot of thall
# 1.Patients with value 2 for thall are at high risk of getting heart attack
#
#
#
#
# 2.   SPLITTING THE DATA:
# Splitting your dataset is essential for an unbiased evaluation of prediction performance. In most cases, it’s enough to split your dataset randomly into three subsets:
#
# The training set ,validation set,the test set

# %% [markdown]
# 3.MACHINE LEARNING MODELS:
# here we used 4 machine learning models
#
#
# 1.   logisticregression
# 2.   decissiontreeclassifier
# 3.   knnclassifier
# 4.   randomforestclassifier
# LOGISTICREGRESSION:
# Basically, it measures the relationship between the categorical dependent variable and one or more independent variables by estimating the probability of occurrence of an event using its logistics function. sklearn.linear_model.LogisticRegression is the module used to implement logistic regression.
#
#
# DECISSIONTREECLASSIFIER:
# Decision Tree classifier implementation in Python with sklearn Library The modeled Decision Tree will compare the new records metrics with the prior records (training data) that correctly classified the balance scale’s tip direction.
#
# KNNCLASSIFIER:
# K-Nearest Neighbor (KNN) Classification and build KNN classifier using Python Sklearn package. KNN is a method that simply observes what kind of data is lies nearest to the one it’s trying to predict. It then classifies the point of interest based on the majority of those around it.
#
#
# RANDOMFORESTCLASSIFIER:
# A random forest is a meta estimator that fits a number of decision tree classifiers on various sub-samples of the dataset and uses averaging to improve the predictive accuracy and control over-fitting. The sub-sample size is controlled with the max_samples parameter if bootstrap=True (default), otherwise the whole dataset is used to build each tree.
